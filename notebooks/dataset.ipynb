# %%
import pandas as pd

# %%
df = pd.read_excel('/Users/siddhantgond/Desktop/shl/dataset/Gen_AI Dataset.xlsx', sheet_name='Sheet1')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# File ~/miniconda3/lib/python3.13/site-packages/pandas/compat/_optional.py:135, in import_optional_dependency(name, extra, errors, min_version)
#     134 try:
# --> 135     module = importlib.import_module(name)
#     136 except ImportError:
#
# File ~/miniconda3/lib/python3.13/importlib/__init__.py:88, in import_module(name, package)
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1324, in _find_and_load_unlocked(name, import_)
#
# ModuleNotFoundError: No module named 'openpyxl'
#
# During handling of the above exception, another exception occurred:
#
# ...

# %%
# !pip install openpyxl
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [openpyxl]1/2 [openpyxl]
# ...

# %%
df = pd.read_excel('/Users/siddhantgond/Desktop/shl/dataset/Gen_AI Dataset.xlsx')

# %%
pd.set_option('display.max_columns', None)

df.head(10)
# Out:
#                                                Query  \
# 0  I am hiring for Java developers who can also c...
# 1  I am hiring for Java developers who can also c...
# 2  I am hiring for Java developers who can also c...
# 3  I am hiring for Java developers who can also c...
# 4  I am hiring for Java developers who can also c...
# 5  I want to hire new graduates for a sales role ...
# 6  I want to hire new graduates for a sales role ...
# 7  I want to hire new graduates for a sales role ...
# 8  I want to hire new graduates for a sales role ...
# 9  I want to hire new graduates for a sales role ...
#
#                                       Assessment_url
# 0  https://www.shl.com/solutions/products/product...
# 1  https://www.shl.com/solutions/products/product...
# 2  https://www.shl.com/solutions/products/product...
# 3  https://www.shl.com/solutions/products/product...
# 4  https://www.shl.com/products/product-catalog/v...
# 5  https://www.shl.com/solutions/products/product...
# ...

# %%
df["Assessment_url"][1]
# Out:
# 'https://www.shl.com/solutions/products/product-catalog/view/core-java-entry-level-new/'

# %%
df["Assessment_url"][2]
# Out:
# 'https://www.shl.com/solutions/products/product-catalog/view/java-8-new/'

# %%
df["Assessment_url"][3]
# Out:
# 'https://www.shl.com/solutions/products/product-catalog/view/core-java-advanced-level-new/'

# %%
df["Assessment_url"][4]
# Out:
# 'https://www.shl.com/products/product-catalog/view/interpersonal-communications/'

# %%
df["Query"][3]
# Out:
# 'I am hiring for Java developers who can also collaborate effectively with my business teams. Looking for an assessment(s) that can be completed in 40 minutes.'
